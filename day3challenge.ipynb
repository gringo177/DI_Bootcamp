# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Task 1
x = np.linspace(0, 20, 100)
y = x**2

# Task 2
plt.plot(x, y)
plt.title('Plot of x vs y')
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(0, 20)
plt.ylim(0, 400)  # You can adjust the y-limit as needed
plt.savefig('daily1.png')
plt.show()

# %%
# Task 1
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv')

# Task 2
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))
plt.scatter(chipo['item_price'], chipo['quantity'])
plt.title('Relationship between Price and Quantity Ordered')
plt.xlabel('Item Price')
plt.ylabel('Quantity Ordered')
plt.savefig('daily2.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
# Task 1
grouped_chipo = chipo.groupby('item_name')['quantity'].sum().sort_values(ascending=False)

# Task 2
top_5_items = grouped_chipo.head(5)
top_5_items.plot(kind='bar')
plt.title('Total Quantities for Top 5 Items')
plt.xlabel('Item Name')
plt.ylabel('Total Quantity')
plt.savefig('daily3.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Task 1
# ----> 2 grouped_chipo = chipo.groupby('item_name')['quantity'].sum().sort_values(ascending=False)
#       4 # Task 2
#       5 top_5_items = grouped_chipo.head(5)
#
# NameError: name 'chipo' is not defined
