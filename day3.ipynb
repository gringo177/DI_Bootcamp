# %%
import matplotlib.pyplot as plt
import numpy as np

#Exercise 2
x = [1, 2, 3, 4, 5]  
y = [5, 4, 3, 2, 1]  

plt.plot(x, y)

plt.show()

#Exercise 3

x = [1, 2, 3, 4, 5]  
y = [75, 80, 88, 95, 105]  

plt.scatter(x, y)

plt.show()

#Exercise 4

x = [1, 2, 3, 4, 5]  
y = [5, 4, 3, 2, 1]  

plt.plot(x, y)
plt.title("Product Demand vs Price")
plt.xlabel("Price")
plt.ylabel("Demand")

plt.show()

#Exercise 5

x = [1, 2, 3, 4, 5]  
y = [75, 80, 88, 95, 105]  

plt.scatter(x, y)
plt.title("Children’s Height vs Age")
plt.xlabel("Age (years)")
plt.ylabel("Height (cm)")

plt.show()

#Exercise 6

plt.plot(x, y)
plt.title("Product Demand vs Price")
plt.xlabel("Price")
plt.ylabel("Demand")
plt.savefig("product_demand_vs_price.png")  
plt.close()

plt.scatter(x, y)
plt.title("Children’s Height vs Age")
plt.xlabel("Age (years)")
plt.ylabel("Height (cm)")
plt.savefig("children_height_vs_age.png")  
plt.close()

#Exercise 7

x = np.linspace(-10, 10, 1000)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, color='tab:blue', label='sin(x)')
plt.scatter(x, y2, marker='o', label='cos(x)')
plt.legend()

plt.show()

#Exercise 8

x = np.linspace(-10, 10, 1000)
y1 = np.sin(x)
y2 = np.cos(x)

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)

ax1.plot(x, y1, color='tab:blue', label='sin(x)')
ax1.legend()

ax2.scatter(x, y2, marker='o', label='cos(x)')
ax2.legend()

plt.show()

#Exercise 9

x = np.linspace(-10, 10, 1000)
y1 = np.sin(x)
y2 = np.cos(x)

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)


ax1.plot(x, y1, color='tab:blue', label='sin(x)')
ax1.legend()

ax2.scatter(x, y2, marker='o', label='cos(x)')
ax2.legend()

fig.legend(loc='upper center', bbox_to_anchor=(0.5, 1.0), fancybox=True, shadow=True)

plt.show()

#Exercise 10

grades = [88, 90, 95, 92, 88, 90, 88, 85, 93, 92, 90, 87, 95, 90, 88]

plt.hist(grades, bins=10, edgecolor='black')

plt.show()
